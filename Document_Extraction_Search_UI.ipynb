# %% [markdown]
# # 🔍 Document Extraction MVP — Interactive Search (Variant E)
#
# This notebook provides:
# - Interactive search interface
# - JSON rendering
# - Constitution / Mathematics / Utility filters
# - SQLite database search UI

# %%
# Run only if widgets not installed
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipywidgets) (9.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.5.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\khusbu pandey\document-extraction-mvp\venv311\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, JSON, HTML
from load_db import DocumentDatabase

# connect database
db = DocumentDatabase("data/documents.db")

print("✅ Database connected")
# Out:
# INFO:load_db:Connected to database: data/documents.db
# INFO:load_db:Database tables created successfully
# ✅ Database connected

# %%
# ================= UI =================

doc_type = widgets.Dropdown(
    options=['constitution','mathematics','utility'],
    value='constitution',
    description='Document:'
)

search_box = widgets.Text(
    placeholder='Enter search query...',
    description='Search:'
)

search_btn = widgets.Button(
    description='🔍 Search',
    button_style='primary'
)

clear_btn = widgets.Button(
    description='🗑️ Clear',
    button_style='warning'
)

output = widgets.Output()
status = widgets.HTML("Ready to search...")

# ================= SEARCH FUNCTION =================

def perform_search(b):

    with output:
        clear_output()

        query = search_box.value.strip()
        dtype = doc_type.value

        if not query:
            print("⚠️ Enter search query")
            return

        status.value = f"Searching {dtype} for '{query}'..."

        try:

            if dtype == "constitution":
                results = db.search_article(query)

            elif dtype == "mathematics":
                results = db.get_theorems(query)

            elif dtype == "utility":
                results = db.filter_location(query)

            if results:
                print(f"✅ Found {len(results)} result(s)\n")
                for r in results:
                    display(JSON(r))
            else:
                print("❌ No results found")

            status.value = "Search complete"

        except Exception as e:
            print("ERROR:", e)
            status.value = "Error occurred"

# ================= BUTTON ACTIONS =================

search_btn.on_click(perform_search)

def clear_results(b):
    search_box.value=""
    with output:
        clear_output()

clear_btn.on_click(clear_results)

# ================= LAYOUT =================

ui = widgets.VBox([
    widgets.HTML("<h2>🔍 Document Search Interface</h2>"),
    doc_type,
    search_box,
    widgets.HBox([search_btn, clear_btn]),
    status,
    output
])

display(ui)
# Out:
# VBox(children=(HTML(value='<h2>🔍 Document Search Interface</h2>'), Dropdown(description='Document:', options=(…
